# %%
# Import functions
from Functions import Wordle_Functions as wrdl
print(f'Version {wrdl.Version} functions loaded')

# %%
# Generate list of words from the main 'Word List.csv' file
word_list = wrdl.fImportList('Word List')
print(f'Total Words: {len(word_list)}')

# %%
# Get random word from list of remaining possibilities 
wrdl.fGetRandom(word_list)

# %%
# Enter results of your guess.  | Black letters are just listed out 'like' | Yellow and Green words are list with an index 't1h2i3s4'
black = 'rh'
yellow = 'h2'
green = 'r1h3'
word_list = wrdl.fLoop(black, yellow, green, word_list)

# %% [markdown]
# ___

# %%
# Added for the ability to view what's currently left in the list
print(word_list)

# %%
# Generate list of words from combined list | This would replace the previously generated list above.
word_list = wrdl.fCombinedLists()
print(f'Total Words: {len(word_list)}')
